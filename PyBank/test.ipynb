# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def integers (n):
    for i in range(n):
        yield i 

integer = integers(5)

# %%
integer
# Out:
# <generator object integers at 0x000002BBBFE46510>

# %%
list(integer)
# Out:
# []

# %%
import os
import csv

# %%
Pybank_csv = os.path.join("Resources", "budget_data.csv")
Pybank_csv
# Out:
# 'Resources\\budget_data.csv'

# %%
all_rows = ""

with open(Pybank_csv) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter = ",")
    next(csv_reader)   
    all_rows = list(csv_reader)

all_rows
# Out:
# [['Jan-10', '1088983'],
#  ['Feb-10', '-354534'],
#  ['Mar-10', '276622'],
#  ['Apr-10', '-728133'],
#  ['May-10', '852993'],
#  ['Jun-10', '563721'],
#  ['Jul-10', '-535208'],
#  ['Aug-10', '632349'],
#  ['Sep-10', '-173744'],
#  ['Oct-10', '950741'],
#  ['Nov-10', '-785750'],
#  ['Dec-10', '-1194133'],
#  ['Jan-11', '-589576'],
#  ['Feb-11', '-883921'],
#  ['Mar-11', '443564'],
#  ['Apr-11', '837887'],
#  ['May-11', '1081472'],
#  ['Jun-11', '464033'],
#  ['Jul-11', '-1066544'],
#  ['Aug-11', '323846'],
#  ['Sep-11', '-806551'],
#  ['Oct-11', '487053'],
#  ['Nov-11', '1128811'],
#  ['Dec-11', '791398'],
#  ['Jan-12', '739367'],
#  ['Feb-12', '-197825'],
#  ['Mar-12', '666016'],
#  ['Apr-12', '589771'],
#  ['May-12', '489290'],
#  ['Jun-12', '-471439'],
#  ['Jul-12', '120417'],
#  ['Aug-12', '175347'],
#  ['Sep-12', '855449'],
#  ['Oct-12', '605195'],
#  ['Nov-12', '-235220'],
#  ['Dec-12', '347138'],
#  ['Jan-13', '298510'],
#  ['Feb-13', '163254'],
#  ['Mar-13', '1141840'],
# ...

# %%
print(f"Total Months: {len(all_rows)}")
# Out:
# Total Months: 86

# %%
Net_total = 0

for row in all_rows:
    print(row)
    num = int(row[1])
    Net_total += num
    
print(f"Total: ${Net_total}")
print(f"Total change: ${Net_change}")

#print("Financial Analysis")
#print("-----------------------------------------")
# Out:
# ['Jan-10', '1088983']
# ['Feb-10', '-354534']
# ['Mar-10', '276622']
# ['Apr-10', '-728133']
# ['May-10', '852993']
# ['Jun-10', '563721']
# ['Jul-10', '-535208']
# ['Aug-10', '632349']
# ['Sep-10', '-173744']
# ['Oct-10', '950741']
# ['Nov-10', '-785750']
# ['Dec-10', '-1194133']
# ['Jan-11', '-589576']
# ['Feb-11', '-883921']
# ['Mar-11', '443564']
# ['Apr-11', '837887']
# ['May-11', '1081472']
# ['Jun-11', '464033']
# ['Jul-11', '-1066544']
# ['Aug-11', '323846']
# ['Sep-11', '-806551']
# ['Oct-11', '487053']
# ['Nov-11', '1128811']
# ['Dec-11', '791398']
# ['Jan-12', '739367']
# ['Feb-12', '-197825']
# ['Mar-12', '666016']
# ['Apr-12', '589771']
# ['May-12', '489290']
# ['Jun-12', '-471439']
# ['Jul-12', '120417']
# ['Aug-12', '175347']
# ['Sep-12', '855449']
# ['Oct-12', '605195']
# ['Nov-12', '-235220']
# ['Dec-12', '347138']
# ['Jan-13', '298510']
# ['Feb-13', '163254']
# ['Mar-13', '1141840']
# ['Apr-13', '542630']
# ['May-13', '99841']
# ['Jun-13', '752765']
# ...

# %%
#num1 = all_rows[0][1]
#print(num1)
dif_list = []
for i in range(85):
    dif_list.append(int(all_rows[i+1][1])- int(all_rows[i][1]))
    print(dif_list)

print(len(dif_list))
    #if i <= 86:
        #num2 = all_rows[i+1][1]
        #dif = int(num2) - int(num1)
        #dif_list.append(dif)
        #num1 = all_rows[i][1]

#print(dif_list)
# Out:
# [-1443517]
# [-1443517, 631156]
# [-1443517, 631156, -1004755]
# [-1443517, 631156, -1004755, 1581126]
# [-1443517, 631156, -1004755, 1581126, -289272]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929, 1167557]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929, 1167557, -806093]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929, 1167557, -806093, 1124485]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929, 1167557, -806093, 1124485, -1736491]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929, 1167557, -806093, 1124485, -1736491, -408383]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929, 1167557, -806093, 1124485, -1736491, -408383, 604557]
# [-1443517, 631156, -1004755, 1581126, -289272, -1098929, 1167557, -806093, 1124485, -1736491, -408383, 604557, -294345]
# ...

# %%
Net_change = 0

for Change in dif_list:
    print(Change)
    Number = int(Change)
    Net_change += Number

Average_change = round((Net_change/85),2)
print(f"Total change: ${Average_change}")
# Out:
# -1443517
# 631156
# -1004755
# 1581126
# -289272
# -1098929
# 1167557
# -806093
# 1124485
# -1736491
# -408383
# 604557
# -294345
# 1327485
# 394323
# 243585
# -617439
# -1530577
# 1390390
# -1130397
# 1293604
# 641758
# -337413
# -52031
# -937192
# 863841
# -76245
# -100481
# -960729
# 591856
# 54930
# 680102
# -250254
# -840415
# 582358
# -48628
# -135256
# 978586
# -599210
# -442789
# 652924
# -1005714
# 1167373
# -234900
# -165147
# -52275
# -302320
# 719028
# -1825558
# 1287083
# -48303
# 210234
# -236414
# 585165
# -1400632
# 839777
# 465229
# 317811
# -760202
# -71868
# 795457
# -182685
# -1242836
# 1371884
# -445193
# 10025
# -1043998
# 1350395
# 80538
# -1223250
# 104148
# 843924
# -1808664
# 1505005
# 306402
# -143603
# -1266937
# -162519
# 1862002
# -52986
# -1627245
# 616795
# 628522
# 90895
# -224669
# Total change: $-8311.11

# %%
Max_list = dif_list[0]
for i in range(85):
    if int(dif_list[i]) > int(Max_list):
        Max_list= dif_list[i]

print(Max_list)

index_max= dif_list.index(Max_list)

print(index_max)

Max_date = all_rows[int(index_max)+1]
print (f"Greatest Increase in Profits: {Max_date[0]} (${Max_list})")
# Out:
# 1862002
# 78
# Greatest Increase in Profits: Aug-16 ($1862002)

# %%
Min_list = dif_list[0]
for i in range(85):
    if int(dif_list[i]) < int(Min_list):
        Min_list= dif_list[i]

print(Min_list)

index_min= dif_list.index(Min_list)

print(index_min)

Min_date = all_rows[int(index_min)+1]
print (f"Greatest Decrease in Profits: {Min_date[0]} (${Min_list})")
# Out:
# -1825558
# 48
# Greatest Decrease in Profits: Feb-14 ($-1825558)
